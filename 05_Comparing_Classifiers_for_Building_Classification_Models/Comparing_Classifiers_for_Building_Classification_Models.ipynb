# %% [markdown]
# <a href="https://colab.research.google.com/github/RoihansLab/Machine-Learning-Projects/blob/main/05_Comparing_Classifiers_for_Building_Classification_Models/Comparing_Classifiers_for_Building_Classification_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Comparing Classifiers for Building Classification Models**
#
# ww'll be comparing the performance of different classifier for ***Building Classification Model***

# %% [markdown]
# ## **1. Make Synthetic Dataset**

# %% [markdown]
# ### **1.1 Import Library**

# %%
from sklearn.datasets import make_classification

# %% [markdown]
# ### **1.2 Generate the datasets**

# %%
X, y = make_classification(n_samples=1000, n_classes= 2, n_features=5, n_redundant=0, random_state=42)

# %% [markdown]
# ### **1.3 Examine the data dimension**

# %%
X.shape
# Out:
# (1000, 5)

# %%
y.shape
# Out:
# (1000,)

# %% [markdown]
# ## **2. Data Split ration (80/20)**

# %% [markdown]
# ### **2.1. Import Library**

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### **2.2. Data Spliting**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# ### **2.3. Examine the data dimension**

# %%
X_train.shape, y_train.shape
# Out:
# ((800, 5), (800,))

# %%
X_test.shape, y_test.shape
# Out:
# ((200, 5), (200,))

# %% [markdown]
# ## **3. Build Classification Models**

# %% [markdown]
# ### **3.1. import modules**

# %%
import pandas as pd
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.linear_model import SGDClassifier

# %% [markdown]
# ### **3.2. Defining learning classifier**

# %%
names = ["Nearest_Neighbors",
         "Linear_SVM",
         "Polynomial_SVM",
         "RBF_SVM",
         "Gaussian_Process",
         "Gradient_Boosting",
         "Decision_Tree",
         "Extra_Trees",
         "Random_Forest",
         "Neural_Net",
         "AdaBoost",
         "Naive_Bayes",
         "QDA",
         "SGD"]

classifier = [
    KNeighborsClassifier(3),
    SVC(kernel="linear", C=0.025),
    SVC(kernel="poly", degree=3, C=0.025),
    SVC(kernel="rbf", C=1, gamma=2),
    GaussianProcessClassifier(1.0 * RBF(1.0)),
    GradientBoostingClassifier(n_estimators=100, learning_rate=1.0),
    DecisionTreeClassifier(max_depth=5),
    ExtraTreesClassifier(n_estimators=10, min_samples_split=2),
    RandomForestClassifier(max_depth=5, n_estimators=100),
    MLPClassifier(alpha=1, max_iter=1000),
    AdaBoostClassifier(n_estimators=100),
    GaussianNB(),
    QuadraticDiscriminantAnalysis(),
    SGDClassifier(loss="hinge", penalty="l2"),
]

# %% [markdown]
# ### **3.3. Build Model, Apply Model on Test Data and Record Accuracy  Score**

# %%
#iterate over classifier
scores = []
for name, clf in zip(names, classifier):
  clf.fit(X_train, y_train)
  score = clf.score(X_test, y_test)
  scores.append(score)

# %%
scores
# Out:
# [0.85,
#  0.825,
#  0.82,
#  0.81,
#  0.835,
#  0.87,
#  0.86,
#  0.865,
#  0.84,
#  0.835,
#  0.825,
#  0.845,
#  0.84,
#  0.84]

# %% [markdown]
# ## **4. Analysis of Model Performance**

# %% [markdown]
# ### **4.1. import library**

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### **4.2. Create data frame of** ***model performance***

# %%
df = pd.DataFrame()
df['name'] = names
df['score'] = scores
df
# Out:
#                  name  score
# 0   Nearest_Neighbors  0.850
# 1          Linear_SVM  0.825
# 2      Polynomial_SVM  0.820
# 3             RBF_SVM  0.810
# 4    Gaussian_Process  0.835
# 5   Gradient_Boosting  0.870
# 6       Decision_Tree  0.860
# 7         Extra_Trees  0.865
# 8       Random_Forest  0.840
# 9          Neural_Net  0.835
# 10           AdaBoost  0.825
# 11        Naive_Bayes  0.845
# 12                QDA  0.840
# 13                SGD  0.840
